# %%
import pandas as pd # impprting pandas

# %%
file=pd.read_csv("Salary_Data.csv")
x=file.iloc[:,:-1].values # Slicing
y=file.iloc[:,-1].values

# %%
file.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
file.isnull().sum() # checking if dataset have any NULL value
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
file.plot(kind='scatter',x='Salary',y='YearsExperience') # plotting
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='YearsExperience'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
print(regressor.predict([[10]]))
# Out:
# [119584.72306999]

# %%
y_pred
# Out:
# array([115814.30756236,  71511.92534771, 102617.85328566,  75282.34085534,
#         55487.65944028,  60200.67882482, 122412.53470072, 107330.8726702 ,
#         63028.49045554,  35692.97802523])

# %%
plt.scatter(x_test,y_pred,color='red')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
import numpy as np
x1=np.array([15,20,22,17,25,24,23])
x1=x1.reshape(x1.shape[0],1)
y1=regressor.predict(x1)
plt.scatter(x1,y1,color='red')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
y1
# Out:
# array([166714.91691537, 213845.11076074, 232697.18829889, 185566.99445352,
#        260975.30460612, 251549.26583704, 242123.22706797])
